# %%
#copy
import json,os
# calpath = '../../CalPoly/crf_all/structure_data'
ashpath = '../../Ashford/Ashford/Ashford/results'
# csuspath = '../../csus/csus/csus/spiders/result'
matchpath = '../cscu_ashford.txt'
secondtxt = '../calpoly_ashford.txt'
first = open(matchpath,'r')
sec = open(secondtxt,'r')
csustxt = first.readlines()
caltxt = sec.readlines()

# print(csustxt)
# with open(matchpath,'r') as f:
#     matchList = f.readlines()

for file in os.listdir(ashpath):
    jsonf = open(os.path.join(ashpath,file), 'r')
    data = json.load(jsonf)
    for idc in data['courses']:
        similist = []
        for i in range(len(csustxt)):
            if idc['id'] in csustxt[i]:
                check = csustxt[i].split(',')
                similist.append(check[0].replace("(","").strip())   
        for j in range(len(caltxt)):
            if idc['id'] in caltxt[j]:
                check = caltxt[j].split(',')
                similist.append(check[0].replace("(","").strip())
        
        if similist: idc['similarTo'] = similist

#     print(data['courses'])
    out = '../addsimJson/ashford'
    compName = os.path.join(out,file)
    with open(compName, 'w') as outf:
        json.dump(data, outf,indent=2)

# %%
import json,os
calpath = '../../CalPoly/crf_all/structure_data'
# ashpath = '../../Ashford/Ashford/Ashford/test'
# csuspath = '../../csus/csus/csus/spiders/result'
matchpath = '../cscu_calpoly.txt'
secondtxt = '../calpoly_ashford.txt'
first = open(matchpath,'r')
sec = open(secondtxt,'r')
csustxt = first.readlines()
caltxt = sec.readlines()

# print(csustxt)
# with open(matchpath,'r') as f:
#     matchList = f.readlines()

for file in os.listdir(calpath):
    jsonf = open(os.path.join(calpath,file), 'r')
    data = json.load(jsonf)
    for idc in data['courses']:
        similist = []
        for i in range(len(csustxt)):
            if idc['id'] in csustxt[i]:
                check = csustxt[i].split(',')
                similist.append(check[0].replace("(","").strip())   
        for j in range(len(caltxt)):
            if idc['id'] in caltxt[j]:
                check = caltxt[j].split(',')
                similist.append(check[1].replace(")","").strip())
        
        if similist: idc['similarTo'] = similist

#     print(data['courses'])
    out = '../addsimJson/calpoly'
    compName = os.path.join(out,file)
    with open(compName, 'w') as outf:
        json.dump(data, outf,indent=2)

# %%
import json,os
# calpath = '../../CalPoly/crf_all/structure_data'
# ashpath = '../../Ashford/Ashford/Ashford/test'
csuspath = '../../csus/csus/csus/spiders/result'
matchpath = '../cscu_calpoly.txt'
secondtxt = '../cscu_ashford.txt'
first = open(matchpath,'r')
sec = open(secondtxt,'r')
csustxt = first.readlines()
caltxt = sec.readlines()


# with open(matchpath,'r') as f:
#     matchList = f.readlines()

for file in os.listdir(csuspath):
    jsonf = open(os.path.join(csuspath,file), 'r')
    data = json.load(jsonf)
    for idc in data['courses']:
        similist = []
        for i in range(len(csustxt)):
            if idc['id'] in csustxt[i]:
                check = csustxt[i].split(',')
                similist.append(check[1].replace(")","").strip())   
        for j in range(len(caltxt)):
            if idc['id'] in caltxt[j]:
                print(idc['id'],caltxt[j])
                check = caltxt[j].split(',')
                similist.append(check[1].replace(")","").strip())
        
        if similist: idc['similarTo'] = similist

#     print(data['courses'])
    out = '../addsimJson/csus'
    compName = os.path.join(out,file)
    with open(compName, 'w') as outf:
        json.dump(data, outf,indent=2)
# Out:
# CSUS_ACCY 1 (CSUS_ACCY 117, AshFord_ACC 407)
#
# CSUS_ACCY 1 (CSUS_ACCY 113, AshFord_ACC 306)
#
# CSUS_ACCY 1 (CSUS_ACCY 113, AshFord_ACC 305)
#
# CSUS_ACCY 1 (CSUS_ACCY 111, AshFord_ACC 306)
#
# CSUS_ACCY 1 (CSUS_ACCY 111, AshFord_ACC 305)
#
# CSUS_ACCY 1 (CSUS_ACCY 112, AshFord_ACC 306)
#
# CSUS_ACCY 1 (CSUS_ACCY 112, AshFord_ACC 305)
#
# CSUS_ACCY 1 (CSUS_ACCY 121, AshFord_ACC 310)
#
# CSUS_ACCY 2 (CSUS_ACCY 262, AshFord_ACC 410)
#
# CSUS_ACCY 111 (CSUS_ACCY 111, AshFord_ACC 306)
#
# CSUS_ACCY 111 (CSUS_ACCY 111, AshFord_ACC 305)
#
# CSUS_ACCY 112 (CSUS_ACCY 112, AshFord_ACC 306)
#
# CSUS_ACCY 112 (CSUS_ACCY 112, AshFord_ACC 305)
#
# CSUS_ACCY 113 (CSUS_ACCY 113, AshFord_ACC 306)
#
# CSUS_ACCY 113 (CSUS_ACCY 113, AshFord_ACC 305)
#
# CSUS_ACCY 117 (CSUS_ACCY 117, AshFord_ACC 407)
#
# CSUS_ACCY 121 (CSUS_ACCY 121, AshFord_ACC 310)
#
# CSUS_ACCY 262 (CSUS_ACCY 262, AshFord_ACC 410)
#
# CSUS_ANTH 1 (CSUS_ANTH 105, AshFord_ANT 307)
#
# CSUS_ANTH 2 (CSUS_ANTH 201, AshFord_ANT 340)
#
# CSUS_ANTH 2 (CSUS_ANTH 2H, AshFord_ANT 101)
#
# CSUS_ANTH 2 (CSUS_ANTH 2, AshFord_ANT 101)
#
# CSUS_ANTH 2H (CSUS_ANTH 2H, AshFord_ANT 101)
#
# CSUS_ANTH 105 (CSUS_ANTH 105, AshFord_ANT 307)
#
# CSUS_ANTH 201 (CSUS_ANTH 201, AshFord_ANT 340)
#
# CSUS_BHON 102 (CSUS_BHON 102, AshFord_BUS 340)
#
# CSUS_BHON 109 (CSUS_BHON 109, AshFord_BUS 644)
#
# CSUS_BHON 120 (CSUS_BHON 120, AshFord_MHA 605)
#
# CSUS_BHON 160 (CSUS_BHON 160, AshFord_BUS 611)
#
# CSUS_BHON 160 (CSUS_BHON 160, AshFord_BUS 697)
#
# CSUS_COMS 2 (CSUS_COMS 221, AshFord_COM 370)
#
# CSUS_COMS 2 (CSUS_COMS 221, AshFord_COM 200)
#
# CSUS_COMS 2 (CSUS_COMS 221, AshFord_COM 101)
#
# CSUS_COMS 2 (CSUS_COMS 222, AshFord_COM 200)
#
# CSUS_COMS 2 (CSUS_COMS 222, AshFord_COM 101)
#
# CSUS_COMS 2 (CSUS_COMS 210, AshFord_COM 345)
#
# CSUS_COMS 2 (CSUS_COMS 215, AshFord_COM 425)
#
# CSUS_COMS 8 (CSUS_COMS 8, AshFord_COM 370)
#
# CSUS_COMS 8 (CSUS_COMS 8, AshFord_COM 200)
#
# CSUS_COMS 21 (CSUS_COMS 210, AshFord_COM 345)
#
# CSUS_COMS 21 (CSUS_COMS 215, AshFord_COM 425)
#
# CSUS_COMS 116 (CSUS_COMS 116, AshFord_COM 370)
#
# CSUS_COMS 116 (CSUS_COMS 116, AshFord_COM 200)
#
# CSUS_COMS 116 (CSUS_COMS 116, AshFord_COM 101)
#
# CSUS_COMS 143 (CSUS_COMS 143, AshFord_COM 200)
#
# CSUS_COMS 160 (CSUS_COMS 160, AshFord_COM 223)
#
# CSUS_COMS 161 (CSUS_COMS 161, AshFord_HPR 303)
#
# CSUS_COMS 164 (CSUS_COMS 164, AshFord_COM 327)
#
# CSUS_COMS 174 (CSUS_COMS 174, AshFord_COM 370)
#
# CSUS_COMS 174 (CSUS_COMS 174, AshFord_COM 200)
#
# CSUS_COMS 174 (CSUS_COMS 174, AshFord_COM 101)
#
# CSUS_COMS 182 (CSUS_COMS 182, AshFord_COM 200)
#
# CSUS_COMS 188 (CSUS_COMS 188, AshFord_COM 370)
#
# CSUS_COMS 210 (CSUS_COMS 210, AshFord_COM 345)
#
# CSUS_COMS 215 (CSUS_COMS 215, AshFord_COM 425)
#
# CSUS_COMS 221 (CSUS_COMS 221, AshFord_COM 370)
#
# CSUS_COMS 221 (CSUS_COMS 221, AshFord_COM 200)
#
# CSUS_COMS 221 (CSUS_COMS 221, AshFord_COM 101)
#
# CSUS_COMS 222 (CSUS_COMS 222, AshFord_COM 200)
#
# CSUS_COMS 222 (CSUS_COMS 222, AshFord_COM 101)
#
# CSUS_CSC 1 (CSUS_CSC 134, AshFord_INF 322)
#
# CSUS_CSC 25 (CSUS_CSC 253, AshFord_CRJ 626)
#
# CSUS_CSC 134 (CSUS_CSC 134, AshFord_INF 322)
#
# CSUS_CSC 253 (CSUS_CSC 253, AshFord_CRJ 626)
#
# CSUS_CRJ 1 (CSUS_CRJ 101, AshFord_CRJ 201)
#
# CSUS_CRJ 1 (CSUS_CRJ 1, AshFord_CRJ 201)
#
# CSUS_CRJ 1 (CSUS_CRJ 172, AshFord_CRJ 613)
#
# CSUS_CRJ 1 (CSUS_CRJ 136, AshFord_CRJ 461)
#
# CSUS_CRJ 1 (CSUS_CRJ 196S, AshFord_CRJ 524)
#
# CSUS_CRJ 2 (CSUS_CRJ 200, AshFord_CRJ 520)
#
# CSUS_CRJ 101 (CSUS_CRJ 101, AshFord_CRJ 201)
#
# CSUS_CRJ 136 (CSUS_CRJ 136, AshFord_CRJ 461)
#
# CSUS_CRJ 172 (CSUS_CRJ 172, AshFord_CRJ 613)
#
# CSUS_CRJ 196 (CSUS_CRJ 196S, AshFord_CRJ 524)
#
# CSUS_CRJ 196S (CSUS_CRJ 196S, AshFord_CRJ 524)
#
# CSUS_CRJ 200 (CSUS_CRJ 200, AshFord_CRJ 520)
#
# CSUS_ECON 192 (CSUS_ECON 192, AshFord_BUS 450)
