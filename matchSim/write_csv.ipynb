# %%
import csv,json,os
#stort in C:\Users\user\Desktop\558project\matchSim
# import sys,io
# sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding="UTF-8")

calpath = '../CalPoly/crf_all/structure_data'
# ashpath = '../Ashford/Ashford/Ashford/results'
# csuspath = '../csus/csus/csus/spiders/result'

f_csv = csv.writer(open("calpoly.csv", "w", newline=''))
f_csv.writerow(["id","subject", "name","units","term", "description"])
for file in os.listdir(calpath):
    jsonf = open(os.path.join(calpath,file), 'r')
    print(jsonf)
    struct = json.load(jsonf)
    try:
        subj = struct['subjectOf']['subject']
    except:
        break
    for x in struct['courses']:
        
        if 'id' in x: 
            idc = x['id']
        else: 
            idc = ''
        if 'course name' in x: 
            name = x['course name']
        else:
            name = ''
        if 'units' in x: 
            units = x['units']
        else:
            units = ''
        if 'term' in x: 
            term = x['term']
        else:
            term = ''
        if 'description' in x:
            des = x['description']
        
    
        f_csv.writerow([idc,subj,name,units,term,des])
# Out:
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Aerospace Engineering (AERO).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Agribusiness (AGB).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Agricultural and Environmental Plant Sciences (AEPS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Agricultural Communication (AGC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Agricultural Education (AGED).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Agriculture (AG).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Animal Science (ASCI).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Anthropology (ANT).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Architectural Engineering (ARCE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Architecture (ARCH).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Art (ART).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Astronomy and Astrophysics (ASTR).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Biology (BIO).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Biomedical Engineering (BMED).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\BioResource and Agricultural Engineering (BRAE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Botany (BOT).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Business (BUS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Chemistry (CHEM).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Child Development (CD).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Chinese (CHIN).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\City and Regional Planning (CRP).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Civil Engineering (CE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Communication Studies (COMS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Computer Engineering (CPE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Computer Science (CSC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Construction Management (CM).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Dairy Science (DSCI).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Dance (DANC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Data Science (DATA).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Early Start English (ESE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Early Start Math (ESM).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Earth Science (ERSC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Economics (ECON).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Education (EDUC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Electrical Engineering (EE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Engineering (ENGR).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\English (ENGL).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Environmental Design (EDES).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Environmental Engineering (ENVE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Ethnic Studies (ES).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Fire Protection Engineering (FPE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Food Science and Nutrition (FSN).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\French (FR).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Geography (GEOG).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Geology (GEOL).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\German (GER).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Graduate Studies (GS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Graduate Studies-Accounting (GSA).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Graduate Studies-Business (GSB).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Graduate Studies-Economics (GSE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Graduate Studies-Packaging (GSP).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Graphic Communication (GRC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Health (HLTH).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\History (HIST).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Honors (HNRS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Honors Contract (HNRC).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Industrial and Manufacturing Engineering (IME).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Industrial Technology and Packaging (ITP).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Interdisciplinary Studies in Liberal Arts (ISLA).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Italian (ITAL).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Japanese (JPNS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Journalism (JOUR).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Kinesiology (KINE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Landscape Architecture (LA).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Liberal Arts and Engineering Studies (LAES).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Liberal Studies (LS).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Marine Science (MSCI).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Materials Engineering (MATE).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Mathematics (MATH).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Mechanical Engineering (ME).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Microbiology (MCRO).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Military Science Leadership (MSL).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Music (MU).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Natural Resources (NR).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Philosophy (PHIL).json' mode='r' encoding='cp950'>
# <_io.TextIOWrapper name='../CalPoly/crf_all/structure_data\\Physical Education' mode='r' encoding='cp950'>
