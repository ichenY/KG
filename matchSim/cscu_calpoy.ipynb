# %%
import os
import csv
import rltk
import re
import sys
import itertools

# %%
file1 = './cscu.csv'
file2 = './calpoly.csv'

# %%
cscu_data = []
calpoly_data = []

# %%
with open(file1, 'r', encoding="utf-8", errors = 'replace') as cscufile:
    reader = csv.DictReader(cscufile)
    for row in reader:
        #print(row)
        data = row['Subject'],row['course name']
        #print(data)
        #data = row['Subject'],row["Course number & title"].replace('\xa0','')
        #print(data)
        cscu_data.append(data)

# %%
with open(file2, 'r', encoding='utf-8-sig') as calpolyfile:
    reader = csv.DictReader(calpolyfile)
    
    for row in reader:
        data = row['Subject'],row["Course number & title"].replace('\xa0','')
        #print(data)
        calpoly_data.append(data)

# %%
import string

def createFeature(data):
    '''
    input: list[tuple[subject, title]]
    output: list[tuple[subject,title,location]]
    '''
    new_data = []
    translate_table = dict((ord(char), ' ') for char in string.punctuation)  

    for loc, row in enumerate(data):
        row = list(row)
        
        ###Subject
        row[0] = row[0].strip()
        
        ###course_name
        row[1] = row[1].translate(translate_table).strip() #replace all punctuations to blank space
        
        ###ID
        row.append(loc + 1) 
        
        new_data.append(tuple(row))
    return list(set(new_data))

# %%
new_cscu = createFeature(cscu_data)
new_calpoly= createFeature(calpoly_data)

# %%
import nltk 
# nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize  

stop_words = set(stopwords.words('english')) 

def hashingFunc(course_name: str) -> str:
    global stop_words
    global translate_table
    return ''.join(sorted([w[0] for w in word_tokenize(course_name) if not w in stop_words]))[:2]
#3hashingFunc(new_cscu)

# %%
from collections import defaultdict
def blockFunc(feature_list):
    """
    Like the idea of hashing data into buckets
    list[tuple[full_subject_name, course_name, word_1st_subject, id]]
    """
    result = defaultdict(list)
    for feature in feature_list:
        if feature[1]:
            k = hashingFunc(feature[1])
            result[k].append(feature)
    #print(result)
    return result

# %%
# nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
cscu = blockFunc(new_cscu)
calpoly = blockFunc(new_calpoly)

# %%
print(sum([len(cscu[k]) for k in cscu.keys()]))
print(sum([len(calpoly[k]) for k in calpoly.keys()]))
# print(len(bucket_keys))

# c = 0
# for k in bucket_keys:
#     if k in cscu and k in calpoly:
#         c+=1
#         #print(len(cscu[k]), len(calpoly[k]))
# print(c)
# Out:
# 4448
# 4127

# %%
count = 0

bucket_keys = set(list(cscu.keys()) + list(calpoly.keys()))
result,allr = [],[]
for k in bucket_keys:
    if k in cscu and k in calpoly:
        for cs, ca in itertools.product(cscu[k], calpoly[k]):
            sub = rltk.levenshtein_similarity(cs[0],ca[0])
            title = rltk.levenshtein_similarity(cs[1],ca[1])

            score = 0.6 * sub + 0.4 * title
            mat = []
            if score > 0.867:
                count += 1
                #if score < 0.9:
                mat.append((cs))
                mat.append((ca))
#                 print(ans)
                result.append(mat)
print(result)
#                 print(cs,ca,score,'count:' + str(count))
# Out:
# [[('Art', 'Beginning Painting', 180), ('Art', 'Beginning Painting', 557)], [('Art', 'Beginning Printmaking', 183), ('Art', 'Beginning Painting', 557)], [('Italian', 'Intermediate Italian', 2792), ('Italian', 'Intermediate Italian I', 2758)], [('Italian', 'Intermediate Italian', 2793), ('Italian', 'Intermediate Italian I', 2758)], [('Art', 'Beginning Sculpture', 195), ('Art', 'Beginning Sculpture', 551)], [('Kinesiology', 'Beginning Sailing', 2848), ('Kinesiology', 'Beginning Swimming', 2819)], [('Kinesiology', 'Beginning Swimming', 2846), ('Kinesiology', 'Beginning Swimming', 2819)], [('French', 'Elementary French', 2113), ('French', 'Elementary French III', 2181)], [('French', 'Elementary French', 2113), ('French', 'Elementary French II', 2180)], [('French', 'Elementary French', 2113), ('French', 'Elementary French I', 2179)], [('French', 'Elementary French', 2114), ('French', 'Elementary French III', 2181)], [('French', 'Elementary French', 2114), ('French', 'Elementary French II', 2180)], [('French', 'Elementary French', 2114), ('French', 'Elementary French I', 2179)], [('Kinesiology', 'Graduate Studies in Kinesiology', 2959), ('Kinesiology', 'Graduate Seminar in Kinesiology', 2912)], [('Geology', 'Igneous and Metamorphic Petrology', 2212), ('Geology', 'Igneous and Metamorphic Petrology', 2227)], [('Music', 'Musicianship I', 3364), ('Music', 'Musicianship III', 3300)], [('Music', 'Musicianship I', 3364), ('Music', 'Musicianship IV', 3329)], [('Music', 'Musicianship I', 3364), ('Music', 'Musicianship II', 3299)], [('Music', 'Musicianship I', 3364), ('Music', 'Musicianship I', 3297)], [('Economics', 'Intermediate Microeconomic Theory', 1184), ('Economics', 'Intermediate Macroeconomics', 1636)], [('Music', 'Musicianship II', 3365), ('Music', 'Musicianship III', 3300)], [('Music', 'Musicianship II', 3365), ('Music', 'Musicianship IV', 3329)], [('Music', 'Musicianship II', 3365), ('Music', 'Musicianship II', 3299)], [('Music', 'Musicianship II', 3365), ('Music', 'Musicianship I', 3297)], [('Economics', 'Intermediate Macroeconomic Theory', 1183), ('Economics', 'Intermediate Macroeconomics', 1636)], [('English', 'Second Language Learning and Teaching', 1695), ('English', 'Theories of Language Learning and Teaching', 1994)], [('Civil Engineering', 'Hydraulics Laboratory', 640), ('Civil Engineering', 'Hydraulics Laboratory', 1168)], [('Geology', 'Applied Geophysics', 2253), ('Geology', 'Applied Geophysics', 2234)], [('Communication Studies', 'Organizational Communication', 853), ('Communication Studies', 'Organizational Communication', 1265)], [('Communication Studies', 'Organizational Communication', 806), ('Communication Studies', 'Organizational Communication', 1265)], [('Economics', 'International Trade', 1212), ('Economics', 'International Trade Theory', 1638)], [('Economics', 'International Trade', 1212), ('Economics', 'International Trade Theory', 1645)], [('Theatre', 'Introduction To Theatre', 4391), ('Theatre', 'Introduction to Theatre', 4005)], [('Economics', 'International Trade', 1234), ('Economics', 'International Trade Theory', 1638)], [('Economics', 'International Trade', 1234), ('Economics', 'International Trade Theory', 1645)], [('Kinesiology', 'Advanced Biomechanics', 2966), ('Kinesiology', 'Advanced Biomechanics', 2904)], [('Anthropology', 'Biological Anthropology Seminar', 148), ('Anthropology', 'Biological Anthropology', 402)], [('Anthropology', 'Biological Anthropology Laboratory', 53), ('Anthropology', 'Biological Anthropology', 402)], [('Economics', 'Industrial Organization', 1203), ('Economics', 'Industrial Organization', 1644)], [('Anthropology', 'Internship', 158), ('Anthropology', 'Internship', 425)], [('English', 'Internships', 1874), ('English', 'Internship', 1974)], [('Anthropology', 'Internship', 131), ('Anthropology', 'Internship', 425)], [('English', 'Literary Theory', 1685), ('English', 'Literary Themes', 1964)], [('Philosophy', 'Metaphysics', 3695), ('Philosophy', 'Metaphysics', 3496)], [('Mathema ...

# %%
#add id to json for CSCU
###CSCU -> CALPOLY
# print(result)
import json
x = 0
newfile = '../match/web'
cscupath = '../match/result_old'
for file in os.listdir(cscupath): 
    fi = open(os.path.join(cscupath,file), 'r')
    
    fi_new = open(os.path.join(newfile,file), 'r')
    subject = content['subject']
    try:
        content_new = json.load(fi_new)
        content = json.load(fi)
        subject = content['subject']
    #     print(content_new['url'])
        content['url'] = content_new['url']
        content['provider'] = content_new['provider']    
        for line in content['course']:
            x += 1
            line['id'] = x
        outfilepath = '../jsonid/jsonid_cscu'
        compName = os.path.join(outfilepath,"%s.json" % subject.strip())
        with open(compName, 'w') as outfile:
            json.dump(content, outfile,indent=2)
    except:
        continue

#     print(content)

# %%
calpath = '../CalPoly/crf_all/structure_data'
y = 0
for file in os.listdir(calpath): 
    fil = open(os.path.join(calpath,file), 'r')
    content = json.load(fil)
    content['provider'] = 'California Polytechnic State University'
    subject = content['subject']
    pos = subject.index('(')
    content['url'] = 'http://catalog.calpoly.edu/coursesaz/'+ subject[pos+1:].replace(')','').lower()
    print(content['url'])
    for line in content['courses']:
        y += 1
        line['id'] = y
    print(content)
# Out:
# http://catalog.calpoly.edu/coursesaz/aero
# {'subject': 'Aerospace Engineering (AERO)', 'courses': [{'Course number & title': ' Aerospace Fundamentals', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Introduction to the engineering profession including the aeronautical and aerospace fields. Engineering approach to problem - solving and analysis of data obtained from experiments. Basic nomenclature and design criteria used in the aerospace industry. Applications to basic problems in the field.', 'grading': 'limited to 9 units', 'format': '1 lecture, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 1}, {'Course number & title': ' Special Problems for Undergraduates', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Individual investigation, research, studies, or surveys of selected problems.', 'grading': 'Total credit limited to 4 units', 'format': '1 lecture, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 2}, {'Course number & title': ' Introduction to Aerospace Design', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F, W', 'Course description': 'Introduction to problem solving techniques and team - centered design projects in aerospace engineering. Primary emphasis on the solutions of design problems in aerospace engineering using computers.', 'grading': 'Total credit limited to 4 units', 'format': '2 laboratories.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 3}, {'Course number & title': ' Aerospace Systems Engineering and Integration', 'Number of units': '1 unit', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Project - based study of fundamental systems engineering concepts including sub - system interface requirements, verification and validation, modeling / analysis / design, and implementation of complex aerospace systems.', 'grading': 'Total credit limited to 4 units', 'format': '1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 4}, {'Course number & title': ' Selected Topics', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Directed group study of selected topics. The Schedule of Classes will list title selected. Total credit', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 5}, {'Course number & title': ' Aerospace Thermodynamics', 'Number of units': '4 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Basics of thermodynamics, energy, systems and control volume analysis. First law, second law, phase change and energy analysis for aerospace - relevant applications. Entropy and exergy, cycle analysis ( Rankine, Brayton, turbojets and turbofans ). Not open to students with credit', 'grading': 'in AERO 301.', 'format': '3 lectures, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 6}, {'Course number & title': ' Aerospace Engineering Analysis', 'Number of units': '5 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Analytical methods for aerospace engineering problems. Topics include vector calculus, linear algebra, differential equations, Laplace transforms and Fourier series. Computer tools and numerical methods as applied to problems in aerodynamics, structures, stability and control and astronautics.', 'grading': 'in AERO 301.', 'format': '4 lectures, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 7}, {'Course number & title': ' Aerospace Fluid Mechanics', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Properties of fluids, statics, mass / energy / momentum for aeronautical applications, external aerodynamics ( lift and drag ), dimensional analysis for scale testing, introduction to differential analysis and Navier - Stokes equations, basics of laminar and turbulent boundary layers.', 'grading': 'in AERO 301.', 'format': '3 lectures, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 8}, {'Co ...
# http://catalog.calpoly.edu/coursesaz/agb
# {'subject': 'Agribusiness (AGB)', 'courses': [{'Course number & title': ' Introduction to Agribusiness', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Orientation to the agribusiness sector of agriculture. An overview of the breadth, size, scope and management aspects of the agricultural business complex. Agribusiness students are required to complete this within the first year of the major.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': '464 substitute for AERO 461,', 'id': 95}, {'Course number & title': ' Special Problems for Undergraduates', 'Number of units': '1-2 units', 'Term': 'CR/NC', 'Course description': 'Individual investigation, research, studies, or surveys of selected problems. Total credit limited to 4 units, with a maximum of 2 units per quarter. Credit can only be used to satisfy free electives. Credit / No Credit grading only.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': '464 substitute for AERO 461,', 'id': 96}, {'Course number & title': ' Introduction to Sales', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Development of professional business - to - business selling principles within the supply chain, including an introduction to understanding the sales process from different buying and selling perspectives, communication techniques, and basic sales competency.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': '464 substitute for AERO 461,', 'id': 97}, {'Course number & title': ' Agricultural Economics', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Theoretical development of factors affecting demand and supply for food and fiber and for agricultural inputs. Methods of selecting optimal levels of agricultural production and consumption variables. Evaluation of market structure and price formulation for agricultural products and resources.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': '464 substitute for AERO 461,', 'id': 98}, {'Course number & title': ' Agribusiness Financial Accounting', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Principles of financial accounting in agribusiness. Preparation for understanding and interpreting financial statements. Exploration of financial reporting standards to provide an understanding of how financial events are reflected in financial statements. The importance of social responsibility in accounting. The accounting cycle, from transactions posting to financial statements through spreadsheet applications.', 'grading': 'limited to 8 units', 'format': '3 lectures, 1 activity.', 'other': '464 substitute for AERO 461,', 'id': 99}, {'Course number & title': ' Agribusiness Data Literacy', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F,W,SP,SU', 'Course description': 'Using data and analysis in making decisions related to agribusiness. Developing basic and intermediate spreadsheet skills necessary to organize, analyze, and summarize information. Development of data management and analysis as tools to assist in agribusiness problem - solving.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': '464 substitute for AERO 461,', 'id': 100}, {'Course number & title': ' Selected Topics', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Directed group study of selected topics. The Schedule of Classes will list title selected. Total credit', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': '464 substitute for AERO 461,', 'id': 101}, {'Course number & title': ' Food and Fiber Marketing', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Food and fiber marketing, examining commodity, industrial, and consumer product marketing from a managerial viewpoint. A g ...
# http://catalog.calpoly.edu/coursesaz/aeps
# {'subject': 'Agricultural and Environmental Plant Sciences (AEPS)', 'courses': [{'Course number & title': ' Orientation to Horticulture and Crop Science', 'Number of units': '2 units', 'Term': 'CR/NC', 'Course description': 'Understand the depth and breadth of horticulture, field crops, and plant protection careers. Examination of curricula within the department. Introduction to both student and professional organizations. Emphasis on curriculum and career planning. Required of all Horticulture and Crop Science students. Credit / No Credit grading only.', 'grading': 'limited to 6 units', 'format': '1 lecture, 1 activity.', 'other': 'in AGB 401.', 'id': 151}, {'Course number & title': ' People, Pests and Plagues', 'Number of units': '4 units', 'Term': 'GE Area B2; GE Area B4', 'Course description': 'Introduction to the science of entomology, focusing on insect identification, biology, ecology, and interactions with humans. Insect pest and beneficial species, and their role in shaping how we live, work and eat. Not open to Agricultural and Environmental Plant Sciences majors or Wine and Viticulture majors ( viticulture concentration ).', 'grading': 'limited to 6 units', 'format': '3 lectures, 1 activity.', 'other': 'in AGB 401.', 'id': 152}, {'Course number & title': ' Principles of Horticulture and Crop Science', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': "Introduction to horticulture and crop science. Basic plant processes, classification, anatomy, physiology, and biotechnology. Effect of environment on plants and how we control it. Introduction to plant growth including propagation, media, irrigation, nutrition, management, harvest, and post harvest handling. People 's use of plants. Field trip required.", 'grading': 'limited to 6 units', 'format': '3 lectures, 1 laboratory.', 'other': 'in AGB 401.', 'id': 153}, {'Course number & title': ' Landscape Installation and Maintenance', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Planting and maintenance of trees, shrubs, ground covers, perennial plantings, color beds, specialty plantings, and small turf areas. Site selection, cultural requirements, scheduling of maintenance activities, pruning, landscape renovation and irrigation system repair. Equipment operation, maintenance, and safety. Speakers from industry.', 'grading': 'limited to 6 units', 'format': '3 lectures, 1 laboratory.', 'other': 'in AGB 401.', 'id': 154}, {'Course number & title': ' Plant Propagation', 'Number of units': '4 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Plant propagation practices with emphasis on understanding why practices are used, how they work, and how they are applied in commercial horticulture. Field trip required.', 'grading': 'limited to 6 units', 'format': '3 lectures, 1 laboratory.', 'other': 'in AGB 401.', 'id': 155}, {'Course number & title': ' Landscape Construction', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Design, construction techniques, and materials used in landscape and horticulture construction. Material quantity estimating, sustainable building practices, construction material substitutions, tools and equipment associated with landscape and horticulture construction, and equipment safety. Field trip required.', 'grading': 'limited to 6 units', 'format': '2 lectures, 1 laboratory.', 'other': 'in AGB 401.', 'id': 156}, {'Course number & title': ' Horticulture and Landscape Design', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Aesthetic aspects of environmental horticulture, introduction to computer aided design, presentation techniques and garden history. Field trip required.', 'grading': 'limited to 6 units', 'format': '2 lectures, 2 laboratories.', 'other': 'in AGB 401.', 'id': 157}, {'Course number & title': ' Pomology I', 'Number of units': '4 units', 'Term': 'Term ...
# http://catalog.calpoly.edu/coursesaz/agc
# {'subject': 'Agricultural Communication (AGC)', 'courses': [{'Course number & title': ' Orientation to Agricultural Communication', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Orientation to the communication sector of agriculture. Overview of professional opportunities and skills needed for success in agricultural communications. Preparation of press releases and short articles, and development of a planned program of study.', 'grading': 'limited to 9 units', 'format': '2 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 234}, {'Course number & title': ' Special Problems in Agricultural Communication', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Individual investigation, research, studies or surveys of selected problems in Agricultural Communication / Agricultural Education. Total credit limited to 8 units, with a maximum of 4 units per quarter.', 'grading': 'limited to 9 units', 'format': '2 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 235}, {'Course number & title': ' Software Applications for Agricultural Publications', 'Number of units': '2 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Emphasis on software applications in agricultural communications, including basic Adobe Creative Suite techniques of InDesign and Lightroom, MS Word and Excel. Best practices in electronic delivery and print. Adobe Premiere video, blog template usage and cloud collaboration for professional agricultural communications.', 'grading': 'limited to 9 units', 'format': '1 lecture, 1 activity.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 236}, {'Course number & title': ' Selected Topics', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Directed group study of selected topics. The Schedule of Classes will list title selected. Total credit', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 237}, {'Course number & title': ' New Media Communication Strategies in Agriculture', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Exploration and implementation of emerging new media communication strategies and technologies to convey information on important issues in agriculture to a global audience. Focus on food and farming dialogues currently populating conversations about production agriculture. Adaptation of different writing styles based on requirements of the various new media channels. Analysis of metrics to measure level of engagement with desired audience.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 238}, {'Course number & title': ' Internship in Agricultural Communications', 'Number of units': '1-12 units', 'Term': 'CR/NC', 'Course description': 'Selected Agricultural Communication students will spend up to 12 weeks with an approved agricultural firm engaged in production or related business. Time will be spent applying and developing production and managerial skills and abilities. One unit of credit may be allowed for each full week of completed and reported internship. Degree credit limited to 6 units. Credit / No Credit grading only.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 239}, {'Course number & title': ' Advanced Special Problems in Agricultural Communication', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Individual investigation, research, studies or surveys of selected problems in Agricultural Communication / Agricultural Education. Total credit limited to 8 units, with a maximum of 4 units per quarter.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures, 1 laboratory.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 240}, {'Course number & ti ...
# http://catalog.calpoly.edu/coursesaz/aged
# {'subject': 'Agricultural Education (AGED)', 'courses': [{'Course number & title': ' Introduction to Agricultural Education', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Overview of agricultural education career pathways including goals and purposes. Kinds of classes and types of programs. Qualifications essential to success in teaching agriculture. Planned program of studies to meet requirement for teaching agricultural science and related disciplines.', 'grading': 'limited to 9 units with not more than 3 units in', 'format': '2 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 253}, {'Course number & title': ' Special Problems in Agricultural Education', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Individual investigation, research, studies or surveys of selected problems in Agricultural Communication / Agricultural Education. Total credit limited to 8 units, with a maximum of 4 units per quarter.', 'grading': 'limited to 9 units with not more than 3 units in', 'format': '2 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 254}, {'Course number & title': ' Agricultural Youth Conferences', 'Number of units': '2 units', 'Term': 'CR/NC', 'Course description': 'Problems encountered and practices applied during the conduct of the annual FFA State Convention. Methods, procedures and materials adapted for use by the student in developing the committee system to produce conferences, conventions and workshops of all kinds and sizes. Total credit limited to 6 units. Credit / No Credit grading only.', 'grading': 'limited to 9 units with not more than 3 units in', 'format': '2 activities.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 255}, {'Course number & title': ' Selected Topics', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Directed group study of selected topics. The Schedule of Classes will list title selected. Total credit', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 256}, {'Course number & title': ' FFA and Supervised Agricultural Experience', 'Number of units': '4 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Historical, philosophical and social foundation of high school agricultural education as it relates to the classroom / laboratory instruction, leadership ( FFA ) and supervised agricultural experiences ( SAEs ). Application of integral components in developing a total program of agricultural education. Two day field study tour required.', 'grading': 'limited to 8 units. 1 to', 'format': '2 lectures, 2 activities.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 257}, {'Course number & title': ' Internship in Agricultural Education', 'Number of units': '1-12 units', 'Term': 'CR/NC', 'Course description': 'Selected Agricultural Education students will spend up to 12 weeks with an approved agricultural firm engaged in production or related business. Time will be spent applying and developing production and managerial skills and abilities. One unit of credit may be allowed for each full week of completed and reported internship. Degree credit limited to 6 units. Credit / No Credit grading only.', 'grading': 'limited to 8 units. 1 to', 'format': '2 lectures, 2 activities.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 258}, {'Course number & title': ' Early Field Experience in Agriculture Education', 'Number of units': '2 units', 'Term': 'Term Typically Offered: W, SP', 'Course description': 'Observation of the practices and techniques utilized by agriculture teachers in conducting organized instruction in high school classrooms, shops, school farms, and laboratories. Discussion of activities and programs unique to teaching agriculture in California secondary schools. Participation in public schools requires mandated fingerprint clearance.', 'grading': 'limited to 8 units. 1 to', 'format': ' ...
# http://catalog.calpoly.edu/coursesaz/ag
# {'subject': 'Agriculture (AG)', 'courses': [{'Course number & title': ' Special Problems for Undergraduates', 'Number of units': '1-2 units', 'Term': 'CR/NC', 'Course description': 'Individual investigation, research, studies, or surveys of selected problems. Total credit limited to 4 units, with a maximum of 2 units per quarter. Credit can only be used to satisfy free electives. Credit / No Credit grading only.', 'grading': 'limited to 9 units with not more than 3 units in', 'format': '3 seminars.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 292}, {'Course number & title': ' Agricultural Leadership Experience', 'Number of units': '1 unit', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Participation in activities that promote personal growth and leadership development, including team work, cooperation, communication, problem solving, time management, and organization. Support CAFES in recruitment, public awareness, educational programs, campus tours, fundraising, and youth career development events. The Class Schedule will list topic selected. Total credit', 'grading': 'limited to 2 units', 'format': '. 1 activity.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 293}, {'Course number & title': ' Leadership Practice: Poly Royal Rodeo', 'Number of units': '3 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Application of the management and operations of the Poly Royal Rodeo event taking place during Open House at Cal Poly. Principles and procedures in planning, organizing, financing, promoting, and managing a major collegiate rodeo and the rodeo industry are discussed.', 'grading': 'limited to 2 units', 'format': '1 lecture, 2 activities.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 294}, {'Course number & title': ' Theory and Practice of Rodeo', 'Number of units': '2 units', 'Term': 'CR/NC', 'Course description': 'Beginning through advanced skills in the event areas of college rodeo. Areas include saddle bronc, bareback, and bull riding ; calf, team, and breakaway roping ; steer wrestling, goat tying, and barrel racing. Minimum of 10 hours of laboratory per week. Total credit limited to 8 units. Credit / No Credit grading. Enrollment limited to those qualified to compete in intercollegiate rodeo.', 'grading': 'limited to 2 units', 'format': '1 lecture, 2 activities.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 295}, {'Course number & title': ' Introduction to Agricultural Leadership', 'Number of units': '2 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Orientation to leadership development in agriculture and related settings. Principles and techniques for developing leadership skills, including exploration of personal characteristics, technical skills, interpersonal influence, commitment, goals, and power necessary for effective leaders. Issues facing leaders in agriculture.', 'grading': 'limited to 2 units', 'format': '2 lectures.', 'other': 'in AEPS 430 or AEPS 433.', 'id': 296}, {'Course number & title': ' Organic Crop Production', 'Number of units': '4 units', 'Term': 'GE Area F', 'Course description': 'Origins, application, regulation and technology of organic crop production. Theoretical and practical issues surrounding organic crop production from a cross - disciplinary perspective. Topics include the history of the organic movement ; current regulation and certification ; and field management practices and technologies. Features industry guest lecturers.', 'grading': 'limited to 2 units', 'format': '3 lectures, 1 activity.', 'other': 'Crosslisted as AEPS / AG315. Fulfills GE Area F.', 'id': 297}, {'Course number & title': ' Cal Poly Land: Nature, Technology, and Society', 'Number of units': '4 units', 'Term': 'GE Area F', 'Course description': 'Scientific investigation of the natural features of the Cal Poly landscape and their transformations by land management technology. Analysis of the environmental, economic, social, and political effects of agriculture, re ...
# http://catalog.calpoly.edu/coursesaz/asci
# {'subject': 'Animal Science (ASCI)', 'courses': [{'Course number & title': ' Introduction to the Animal Sciences', 'Number of units': '2 units', 'Term': 'CR/NC', 'Course description': 'Economic, environmental and societal impact of the livestock, poultry and horse industries. Basic terminology, anatomy, and physical requirements of animals. Career and academic planning. Co - curricular, extra - curricular, and post - graduate opportunities. Required of all first - time students in the Animal Science Department. Credit / No Credit grading only.', 'grading': 'limited to 6 units', 'format': '2 lectures.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 318}, {'Course number & title': ' Principles of Animal Science', 'Number of units': '4 units', 'Term': 'GE Area B2', 'Course description': 'Comparative physiology of digestive, endocrine, and reproductive systems in animals. Principles of nutrition, genetics, growth and development, behavior, food processing / safety of animals. Current issues in animal agriculture including biosecurity, animal welfare, and governmental safeguards for animal and human health. 4 lectures. Fulfills GE B2 except for ASCI majors.', 'grading': 'limited to 6 units', 'format': '2 lectures.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 319}, {'Course number & title': ' Special Problems', 'Number of units': '1-4 units', 'Term': 'CR/NC', 'Course description': 'Individual investigation, research, studies, or surveys of selected problems. Total credit limited to 4 units, with a maximum of 3 units per quarter. Credit / No Credit grading only.', 'grading': 'limited to 6 units', 'format': '2 lectures.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 320}, {'Course number & title': ' Animal Parasitology', 'Number of units': '3 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Identification, life cycles, prevention and control of the common external and internal parasites causing economic loss in livestock.', 'grading': 'limited to 6 units', 'format': '3 lectures.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 321}, {'Course number & title': ' Meat Science', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Muscle food processing methods and operations. Conversion of muscle to meat. Meat inspection, grading, composition, curing, preservation, food safety and related topics. Carcass beef, pork, and lamb processed into consumer ready products.', 'grading': 'limited to 6 units', 'format': '3 lectures, 1 laboratory.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 322}, {'Course number & title': ' Livestock Show Management', 'Number of units': '3 units', 'Term': 'Term Typically Offered: W', 'Course description': "Application of the management and operations of Cal Poly 's Western Bonanza Livestock Show. Principles and procedures in planning, organizing, financing, promoting and managing a major livestock show and the fair industry. Total credit limited to 6 units. Not open to students with credit for ASCI412 or ASCI413.", 'grading': 'limited to 6 units', 'format': '1 lecture, 2 activities.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 323}, {'Course number & title': ' Equine Management', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Application of safety, risk reduction, horsemanship skills. Develop a working equine / human relationship. Selection and application of nutrition, equipment, preventive health and farrier program, and equitation skills.', 'grading': 'limited to 6 units', 'format': '2 laboratories.', 'other': 'Crosslisted as AG / ASCI360. Fulfills GE Area F.', 'id': 324}, {'Course number & title': ' Introductory Animal Nutrition and Feeding', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Nutrient digestion and absorpt ...
# http://catalog.calpoly.edu/coursesaz/ant
# {'subject': 'Anthropology (ANT)', 'courses': [{'Course number & title': ' Special Problems for Undergraduates', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Individual investigation, research, studies, or surveys of selected problems. Total credit limited to 8 units, with a maximum of 4 units per quarter.', 'grading': 'limited to 10 units.', 'format': '1 - 4 seminars.', 'other': 'Crosslisted as ASCI / BIO / BMED594.', 'id': 399}, {'Course number & title': ' Cultural Anthropology', 'Number of units': '4 units', 'Term': 'GE Area D3', 'Course description': 'Contemporary human cultures throughout the world. General patterns sought within the diversity of individual cultures. Includes such topics as : family organization ; gender roles ; adaptation to the environment ; systems of economic exchange ; political organization and leadership ; religious beliefs and values ; ethnicity and cultural pluralism ; impact of Western culture on the developing world.', 'grading': 'limited to 10 units.', 'format': '4 lectures.', 'other': 'Fulfills GE D3.', 'id': 400}, {'Course number & title': ' World Prehistory', 'Number of units': '4 units', 'Term': 'GE Area D3', 'Course description': 'Development of the diverse human cultures of both the Old and New Worlds from the emergence of the first human ancestors ( hominins ) to the dawn of history ; biological evolution, global cultural development, and adaptation before the advent of writing.', 'grading': 'limited to 10 units.', 'format': '4 lectures.', 'other': 'Fulfills GE D3.', 'id': 401}, {'Course number & title': ' Biological Anthropology', 'Number of units': '4 units', 'Term': 'GE Area B2', 'Course description': 'Biological aspects of human unity and diversity. Primate and human evolution, including anatomical, physiological and behavioral adaptations. Origin and diversity of modern races.', 'grading': 'limited to 10 units.', 'format': '4 lectures.', 'other': 'Fulfills GE D3.', 'id': 402}, {'Course number & title': ' Selected Topics', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Directed group study of selected topics. The Schedule of Classes will list title selected. Total credit', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'Fulfills GE D3.', 'id': 403}, {'Course number & title': ' Elements of Archaeology', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Archaeological method and theory covering the history and development of archaeological thought, approaches to data recovery, dating and analysis of artifacts and ecofacts, the construction of models of prehistoric human behavior through application of archaeological and anthropological theories.', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'Fulfills GE D3.', 'id': 404}, {'Course number & title': ' Archaeological Field Methods', 'Number of units': '4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Hands - on introduction to the methods and techniques of archaeology with an emphasis on excavation. Training in artifact and ecofact identification with a focus on lithic technology. Practical field experience with hand tools, and stratigraphic interpretation. Methodological approaches to both academic research questions and compliance with environmental planning mandates.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures, 1 laboratory.', 'other': 'Fulfills GE D3.', 'id': 405}, {'Course number & title': ' Archaeological Laboratory Methods', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Hands - on introduction to the methods employed in post - field processing, classification, analysis, and preservation of archaeological materials. Compilation of quantitative and qualitative information in data base format to assist in the classification and interpretation of faunal remains and ...
# http://catalog.calpoly.edu/coursesaz/arce
# {'subject': 'Architectural Engineering (ARCE)', 'courses': [{'Course number & title': ' Introduction to Building Systems', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Introduction to building systems and materials. Use and application of structural, foundation, envelope, mechanical and electrical systems in the field of Architectural Engineering.', 'grading': 'limited to 8 units. 1 to', 'format': '1 lecture, 1 activity.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 427}, {'Course number & title': ' Structures I', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F,W,SP,SU', 'Course description': 'Introduction to the role of structures in the making of buildings. Introduction to statics and creation of simple three - dimensional structures. Development of skills to analyze structures composed of axial force ( truss ) members.', 'grading': 'limited to 8 units. 1 to', 'format': '2 lectures, 1 activity.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 428}, {'Course number & title': ' Structures II', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F,W,SP,SU', 'Course description': 'Introduction to the role of structures in the making of buildings. Introduction to shear and moment diagrams using the principles of statics and the application of the diagrams to simple three - dimensional structures. Development of skills, particularly free body diagrams, to analyze structures composed of bending ( beams ) members.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 429}, {'Course number & title': ' Mechanics of Structural Members', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F, SP', 'Course description': 'Advanced topics of stresses in beams. Plastic bending, unsymmetrical bending. Combined stresses. Stress transformation. Buckling. Deflection of beams.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 430}, {'Course number & title': ' Mechanics of Structural Members Laboratory', 'Number of units': '1 unit', 'Term': 'Term Typically Offered: F, SP', 'Course description': 'Experimental investigations of material properties. Experimental studies of stresses and deflections in beams, including plastic bending, and unsymmetrical bending. Stress transformations via strain gages for combined loading cases. Culminating lab experience : A student run, self - designed experiment.', 'grading': 'limited to 8 units. 1 to', 'format': '1 laboratory.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 431}, {'Course number & title': ' Introduction to Structural Systems', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F,W,SP,SU', 'Course description': 'Description, behavior and comparison of structural building systems. Concepts of structural stability, load flow, framing schemes and building configuration related to vertical and lateral loads. Not open to Architectural Engineering majors.', 'grading': 'limited to 8 units. 1 to', 'format': '3 lectures.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 432}, {'Course number & title': ' Structures III', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F, SP', 'Course description': 'Continuation of selected concepts covered in ARCE211 and ARCE212. Advanced topics in two - dimensional and three - dimensional equilibrium of structural building systems.', 'grading': 'limited to 8 units. 1 to', 'format': '2 lectures.', 'other': 'Crosslisted as ANT / GEOG455.', 'id': 433}, {'Course number & title': ' Structural CAD for Building Design', 'Number of units': '2 units', 'Term': 'Term Typically Offered: W, SP', 'Course description': "Emphasis on the use of computer graphics software to represent a building 's structural system and its individual elements.", 'grading': 'limited to 8 units. 1 to', 'format': '1 lecture, 1 laboratory.', 'other': 'Crosslisted as ANT / GE ...
# http://catalog.calpoly.edu/coursesaz/arch
# {'subject': 'Architecture (ARCH)', 'courses': [{'Course number & title': ' Survey of Architectural Education and Practice', 'Number of units': '1 unit', 'Term': 'CR/NC', 'Course description': 'Exploration of the major paradigms which have guided the development of architectural education and the profession. Survey of the roles of the architects and an introduction to curricula and programs designed to prepare students for careers in architecture. Credit / No Credit grading only. 1 lecture. Total credit', 'grading': 'limited to 3 units', 'format': '3 laboratories.', 'other': 'Fulfills GE C3.', 'id': 485}, {'Course number & title': ' Materials of Construction', 'Number of units': '2 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Use and application of construction processes and materials.', 'grading': 'limited to 3 units', 'format': '2 lectures.', 'other': 'Fulfills GE C3.', 'id': 486}, {'Course number & title': ' Design and Visual Communication 1', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': 'An introduction to the issues, concepts, processes and skills pertaining to two- and three - dimensional design and the freehand, constructed and digital representation and visual communication of ideas, objects and environments. Purchase of a laptop computer, software and peripherals is highly recommended to participate in this course.', 'grading': 'limited to 3 units', 'format': '4 laboratories.', 'other': 'Fulfills GE C3.', 'id': 487}, {'Course number & title': ' Design and Visual Communication 1', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Continuation of ARCH131 plus the issues, concepts, processes and skills pertaining to color theory and the design and visual communication of architectural space. Purchase of a laptop computer, software and peripherals is highly recommended to participate in this course.', 'grading': 'limited to 3 units', 'format': '4 laboratories.', 'other': 'Fulfills GE C3.', 'id': 488}, {'Course number & title': ' Design and Visual Communication 1', 'Number of units': '4 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Continuation of ARCH131 and ARCH132 plus the issues, concepts, processes and skills pertaining to the analysis and design of architectural form, space and organizations. Purchase of a laptop computer, software and peripherals is highly recommended to participate in this course.', 'grading': 'limited to 3 units', 'format': '4 laboratories.', 'other': 'Fulfills GE C3.', 'id': 489}, {'Course number & title': ' Architectural Theory', 'Number of units': '3 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Theories of architectural design.', 'grading': 'limited to 3 units', 'format': '3 lectures.', 'other': 'Fulfills GE C3.', 'id': 490}, {'Course number & title': ' Architectural Technology Fundamentals 2', 'Number of units': '4 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Theory and application of climate, energy use and comfort as determinants of architectural form in small - scale buildings. Emphasis on architectural methods of ventilating, cooling, heating, and lighting for envelope - load dominated buildings.', 'grading': 'limited to 3 units', 'format': '2 lectures, 2 activities.', 'other': 'Fulfills GE C3.', 'id': 491}, {'Course number & title': ' History of World Architecture: Prehistory - Middle Ages', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Architecture and urbanism in the ancient world, from prehistory to the Middle Ages. Social, cultural and physical conditions that influenced the built environment to the Mediterranean basis, plus Europe, Asia, Africa and Pre - Columbian America.', 'grading': 'limited to 3 units', 'format': '4 lectures.', 'other': 'Fulfills GE C3.', 'id': 492}, {'Course number & title': ' History of World Architecture: Middle Ages - 18th Century', 'Number of units': '4 ...
# http://catalog.calpoly.edu/coursesaz/art
# {'subject': 'Art (ART)', 'courses': [{'Course number & title': ' The Fundamentals of Drawing', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Introduction to the artistic practice and cultural value of drawing from the Renaissance to the 21st Century. Emphasis and expansion of the practical skills of observation, rendering, and understanding the signs of meaning produced in visual art. Development of formal techniques, media experimentation, and content creation through personal expression. Exercises to encourage growth in technical skill, conceptual innovation, critical thinking, and visual communication.', 'grading': 'limited to 9 units', 'format': '3 lectures, 1 laboratory.', 'other': 'Fulfills GE C3.', 'id': 544}, {'Course number & title': ' Art and Design Foundation Studies I', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Introduces elements and principles of design, establishing a foundation for all artistic practice. Emphasizing critical thinking and creative problem solving, the interrelationship between form and content are examined. Traditional, digital and lens - based media are explored through individual and collaborative experiences.', 'grading': 'limited to 9 units', 'format': '3 lectures, 1 laboratory.', 'other': 'Fulfills GE C3.', 'id': 545}, {'Course number & title': ' Art and Design Foundation Studies II', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Visual and aesthetic interactions of color, examined through historical and contemporary models. Formal techniques, media experimentation and content creation, explored through individual and collaborative experiences.', 'grading': 'limited to 9 units', 'format': '3 lectures, 1 laboratory.', 'other': 'Fulfills GE C3.', 'id': 546}, {'Course number & title': ' Art and Design Foundation Studies III', 'Number of units': '4 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'Principles and essential skills for three - dimensional practice in art and design. Understanding, envisioning, and communicating effectively about space, objects, scale, and the relationship of the body to the built environment.', 'grading': 'limited to 9 units', 'format': '3 lectures, 1 laboratory.', 'other': 'Fulfills GE C3.', 'id': 547}, {'Course number & title': ' Introduction to Art', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Designed to acquaint the non - art major with painting, sculpture, drawing, crafts, architecture and printmaking. Development of vocabulary, analytic skills, and research techniques for the understanding of art objects.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Fulfills GE C3.', 'id': 548}, {'Course number & title': ' Survey of Western Art', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'History of major art movements in western civilization from ancient art to the twentieth century. Representative periods of western culture, such as the ancient world, the Middle Ages, the Renaissance, and the modern world.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Fulfills GE C3.', 'id': 549}, {'Course number & title': ' Basic Digital Photography', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Fundamental techniques in photography. Mechanics of digital cameras, optics, composition, perception of light and subject content. Understanding photographic principles and the language of camera vision. Introduction to the impact of photography on culture. Digital camera required.', 'grading': 'limited to 9 units', 'format': '3 lectures, 1 laboratory.', 'other': 'Fulfills GE C3.', 'id': 550}, {'Course number & title': ' Beginning Sculpture', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Exploration of three dimensional form through problems in modeling, casting, carving, and techniques of a ...
# http://catalog.calpoly.edu/coursesaz/astr
# ...
# http://catalog.calpoly.edu/coursesaz/mu
# {'subject': 'Music (MU)', 'courses': [{'Course number & title': ' Introduction to Music Theory', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Introduction to the elements of music and their use by composers and performers. Notation of pitch and rhythm, scales, key signatures, intervals and chords.', 'grading': 'limited to 8 units', 'format': '3 lectures, 1 activity.', 'other': 'Fulfills GE C3.', 'id': 3295}, {'Course number & title': ' Music Theory I: Diatonic Materials', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W', 'Course description': 'Introduction to species counterpoint, structure of tonality, four - part writing of root position and inverted triads, dominant seventh chord, phrase structure, harmonic progressions, harmonization of a melody and nonharmonic tones. Composition project.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': 'Fulfills GE C3.', 'id': 3296}, {'Course number & title': ' Musicianship I', 'Number of units': '2 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Introductory sightsinging in the major mode ; rhythmic performance and dictation in simple and compound meters ; identification and performance of melodic and harmonic intervals and triads ; dictation of major diatonic melodies and chord progressions using the primary triads.', 'grading': 'limited to 8 units', 'format': '2 activities.', 'other': 'Fulfills GE C3.', 'id': 3297}, {'Course number & title': ' Music Theory II: Chromatic Materials', 'Number of units': '4 units', 'Term': 'Term Typically Offered: W, SP', 'Course description': 'Construction and resolution of diatonic seventh chords, secondary dominants, augmented sixth, and Neapolitan chords. Modal mixture and modulation to closely - related keys. Binary, ternary, and variation forms. Introduction to 18th - century counterpoint. Composition project.', 'grading': 'limited to 8 units', 'format': '4 lectures.', 'other': 'Fulfills GE C3.', 'id': 3298}, {'Course number & title': ' Musicianship II', 'Number of units': '2 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Sightsinging and dictation in major and minor modes ; performance and dictation of one- and two - part rhythms in simple and compound meters ; syncopation ; identification of compound intervals, triad inversions and cadence types ; harmonic dictation using diatonic root position triads and the dominant seventh.', 'grading': 'limited to 8 units', 'format': '2 activities.', 'other': 'Fulfills GE C3.', 'id': 3299}, {'Course number & title': ' Musicianship III', 'Number of units': '2 units', 'Term': 'Term Typically Offered: SP', 'Course description': 'One- and two - part sightsinging and melodic dictation ; alto and tenor clefs ; one- and two - part rhythmic performance and dictation including syncopation and triplets ; harmonic dictation including diatonic triads in all inversions and dominant and supertonic seventh chords ; identification of phrase structure.', 'grading': 'limited to 8 units', 'format': '2 activities.', 'other': 'Fulfills GE C3.', 'id': 3300}, {'Course number & title': ' Introduction to Composing', 'Number of units': '4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Fundamental concepts in music composition. Creative projects. Compositional techniques, development, and structure. Analysis of examples from the literature.', 'grading': 'limited to 8 units', 'format': '3 lectures, 1 activity.', 'other': 'Fulfills GE C3.', 'id': 3301}, {'Course number & title': ' Music Appreciation', 'Number of units': '4 units', 'Term': 'GE Area C3', 'Course description': 'Explores the world of music with emphasis on Western tradition. Language of music, the role of music in society. Historical context and major composers from the Middle Ages to the present.', 'grading': 'limited to 8 units', 'format': '3 lectures, 1 activity.', 'other': 'Fulfills GE C3.', 'id': 3302}, {'Course number & title': ' Introduct ...
# http://catalog.calpoly.edu/coursesaz/nr
# {'subject': 'Natural Resources (NR)', 'courses': [{'Course number & title': ' Careers in Natural Resources Management and Environmental Sciences', 'Number of units': '1 unit', 'Term': 'CR/NC', 'Course description': 'Analysis and development of career goals in natural resources and environmental sciences. Acquainting students with potential career options and preparation of academic plans for the majors in the Natural Resources Management and Environmental Sciences Department. Credit / No Credit grading.', 'grading': 'limited to 8 units.', 'format': '1 activity.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3391}, {'Course number & title': ' Introduction to Forest Ecosystem Management', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Fundamentals of forestry including basic silviculture, forest protection, measurement and policy. Integrated resource management of forest lands for water production, forage, recreation, wildlife, and timber.', 'grading': 'limited to 8 units.', 'format': '3 lectures.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3392}, {'Course number & title': ' Environmental Management', 'Number of units': '3 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Environmental management as a process within functioning societies seeking a harmonious balance between human activities and intrinsic behavior of the natural environment. Major components of the natural environment and the political and social activities that impact that environment.', 'grading': 'limited to 8 units.', 'format': '3 lectures.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3393}, {'Course number & title': ' Resource Law Enforcement', 'Number of units': '3 units', 'Term': 'Term Typically Offered: W', 'Course description': 'Law enforcement applied to natural resource conservation on public and private lands. Examination of state and federal laws related to fish and wildlife management. Problems associated with implementation of resource laws examined.', 'grading': 'limited to 8 units.', 'format': '3 lectures.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3394}, {'Course number & title': ' Wildland Fire Control', 'Number of units': '3 units', 'Term': 'Term Typically Offered: SP', 'Course description': "Fire control techniques used on various wildland fuels. Elementary fire physics, fuels, weather, fire behavior, tactics and fire suppression techniques, line construction, ' mop - up ', fire line safety, air operations and fire organization. Meets basic wildland fire fighter certification requirements for the USDA Forest Service. Partially meets California Department of Forestry Firefighter I requirements.", 'grading': 'limited to 8 units.', 'format': '2 lectures, 1 laboratory.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3395}, {'Course number & title': ' Dendrology', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Identification, classification, silvical characteristics, distribution, environmental requirements and economic importance of woody plants in shrub, woodland, and forest ecosystems of the United States. Emphasis on species located in the Pacific Coastal, Sierran, and Cascade ecosystems.', 'grading': 'limited to 8 units.', 'format': '2 lectures, 2 laboratories.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3396}, {'Course number & title': ' Land and Resource Measurements', 'Number of units': '1 unit', 'Term': 'Term Typically Offered: F, W, SP', 'Course description': 'Introduction to land and resource measurement technology and methods - field instruments, property description, map and photograph reconciliation, data accuracy and precision. Trigonometric functions as applied to natural resources applications. Field trips required.', 'grading': 'limited to 8 units.', 'format': '1 laboratory.', 'other': 'Crosslisted as ERSC / NR140.', 'id': 3397}, {'Course number & title': ' Applications in GIS', 'Number of units':  ...
# http://catalog.calpoly.edu/coursesaz/phil
# {'subject': 'Philosophy (PHIL)', 'courses': [{'Course number & title': ' Introduction to Philosophy', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': 'Foundational methods and central issues in contemporary philosophy including logic, epistemology, metaphysics and ethics. Required of all philosophy majors. Open to all majors and philosophy minors.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3457}, {'Course number & title': ' Logic and Argumentative Writing', 'Number of units': '4 units', 'Term': 'GE Area A3', 'Course description': 'Principles of argument analysis, evaluation and construction. Deductive and inductive reasoning, including analogical arguments, universal and statistical generalizations, and causal inferences. Principles of organizing and writing argumentative essays. Moral dimensions of rational discourse. 4 lectures. Fulfills GE A3 ; for students admitted Fall 2016 or later a grade of C- or better is required to fulfill GE Area A3.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3458}, {'Course number & title': ' Philosophical Classics: Knowledge and Reality', 'Number of units': '4 units', 'Term': 'GE Area C2', 'Course description': 'Critical examination of primary philosophical texts, from the ancient and modern periods, with focus on the nature of reality and the sources and limits of human knowledge. 4 lectures. Crosslisted as HNRS / PHIL230. Fulfills GE C2.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3459}, {'Course number & title': ' Philosophical Classics: Ethics and Political Philosophy', 'Number of units': '4 units', 'Term': 'GE Area C2', 'Course description': 'Readings from primary philosophical texts, from the ancient and modern periods, with focus on the identification, evaluation and contemporary relevance of the central ethical and political themes and arguments presented in them. Course may be offered in classroom - based or online format. 4 lectures. Crosslisted as HNRS / PHIL231. Fulfills GE C2.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3460}, {'Course number & title': ' Symbolic Logic', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F, SP', 'Course description': 'The nature of deductive logical systems. Methods of notation, translation and proof in sentential and predicate calculi including truth - trees and natural deduction systems. Introduction to meta - theory.', 'grading': 'limited to 9 units', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3461}, {'Course number & title': ' Selected Topics', 'Number of units': '1-4 units', 'Term': 'Term Typically Offered: TBD', 'Course description': 'Directed group study of selected topics. The Schedule of Classes will list title selected. Total credit', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3462}, {'Course number & title': ' Ethics Bowl', 'Number of units': '4 units', 'Term': 'Term Typically Offered: F', 'Course description': "Preparation for competition in the Intercollegiate Ethics Bowl. Rules and format of competition, analysis and preparation of cases specific to the current year 's competition. Coverage of ethical theory relevant to current cases. Field trips required.", 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'other': 'Crosslisted as ERSC / NR478.', 'id': 3463}, {'Course number & title': ' Early Greek Philosophy through Plato', 'Number of units': '4 units', 'Term': 'GE Area C4', 'Course description': 'Beginnings of Western philosophy and science in Ancient Greece. The Presocratics, Socrates, and Plato. 4 lectures. Fulfills GE C4 except for Philosophy majors.', 'grading': 'limited to 8 units. 1 to', 'format': '4 lectures.', 'othe ...
